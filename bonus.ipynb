# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import psycopg2
from config import username, password 
from sqlalchemy import create_engine

# %%
# making variables for username and password 

username = username
password = password

#path to data base 

engine = create_engine(f'postgresql://{username}:{password}@localhost:5432/sql-challenge')
conn = engine.connect()

# %%
salary = pd.read_sql("select * from salaries", conn)
salary.head()
# Out:
#    emp_no   salary
# 0   10001  60117.0
# 1   10002  65828.0
# 2   10003  40006.0
# 3   10004  40054.0
# 4   10005  78228.0

# %%
#plotting the histogram 

fig=plt.figure(figsize=[20,10])
plt.hist(salary['salary'], 10, histtype = 'bar', facecolor= 'blue')
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Salary',fontsize=15)
plt.ylabel('Employee Frequency',fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title('Common Salary Ranges Histogram',fontsize=15)
plt.show()

# %%
#getting employee data

employee_data =pd.read_sql("select * from employees", conn)
employee_data.head()
# Out:
#    emp_no                       emp_title  birth_date  first_name  last_name  \
# 0  473302  s0001                           1953-07-25    Hideyuki   Zallocco
# 1  475053  e0002                           1954-11-18       Byong  Delgrande
# 2   57444  e0002                           1958-01-30       Berry       Babb
# 3  421786  s0001                           1957-09-28       Xiong   Verhoeff
# 4  282238  e0003                           1952-10-28  Abdelkader    Baumann
#
#   sex   hire_date
# 0   M  1990-04-28
# 1   F  1991-09-07
# 2   F  1992-03-21
# 3   M  1987-11-26
# 4   F  1991-01-18

# %%
#getting title data 

title_data =pd.read_sql("select * from titles", conn)

#renaming to match

title_data.rename(columns = {'title_id':'emp_title'}, inplace = True)
title_data
# Out:
#                         emp_title               title
# 0  s0001                                        Staff
# 1  s0002                                 Senior Staff
# 2  e0001                           Assistant Engineer
# 3  e0002                                     Engineer
# 4  e0003                              Senior Engineer
# 5  e0004                             Technique Leader
# 6  m0001                                      Manager

# %%
#merge the title and employee to get the employee number

title_emp = pd.merge(title_data, employee_data, on='emp_title', how='left' )
title_emp.head()
# Out:
#                         emp_title  title  emp_no  birth_date  first_name  \
# 0  s0001                           Staff  473302  1953-07-25    Hideyuki
# 1  s0001                           Staff  421786  1957-09-28       Xiong
# 2  s0001                           Staff  273487  1957-04-14   Christoph
# 3  s0001                           Staff  246449  1958-03-23       Subbu
# 4  s0001                           Staff   48085  1964-01-19  Venkatesan
#
#     last_name sex   hire_date
# 0    Zallocco   M  1990-04-28
# 1    Verhoeff   M  1987-11-26
# 2     Parfitt   M  1991-06-28
# 3  Bultermann   F  1988-03-25
# 4        Gilg   M  1993-06-28

# %%
#merge title_emp with salary data

salary_title = pd.merge(salary, title_emp, on = 'emp_no', how = 'left')
salary_title.head()
# Out:
#    emp_no   salary                       emp_title            title  \
# 0   10001  60117.0  e0003                           Senior Engineer
# 1   10002  65828.0  s0001                                     Staff
# 2   10003  40006.0  e0003                           Senior Engineer
# 3   10004  40054.0  e0003                           Senior Engineer
# 4   10005  78228.0  s0001                                     Staff
#
#    birth_date first_name last_name sex   hire_date
# 0  1953-09-02     Georgi   Facello   M  1986-06-26
# 1  1964-06-02    Bezalel    Simmel   F  1985-11-21
# 2  1959-12-03      Parto   Bamford   M  1986-08-28
# 3  1954-05-01  Chirstian   Koblick   M  1986-12-01
# 4  1955-01-21    Kyoichi  Maliniak   M  1989-09-12

# %%
#get the average salary by title

average_salary = salary_title.groupby('title')['salary'].mean().reset_index()
average_salary
# Out:
#                 title        salary
# 0  Assistant Engineer  48564.434447
# 1            Engineer  48535.336511
# 2             Manager  51531.041667
# 3     Senior Engineer  48506.799871
# 4        Senior Staff  58550.172704
# 5               Staff  58465.382850
# 6    Technique Leader  48582.896092

# %%
#plot the bar graph

fig2=plt.figure(figsize=[20,10])
plt.grid(axis = 'y')
plt.bar(range(len(average_salary)), average_salary['salary'], color = 'blue')
plt.xlabel('Titles',fontsize=15)
plt.xticks(range(len(average_salary)), average_salary['title'],fontsize=15)
plt.ylabel('Average salary', fontsize = 15)
plt.yticks(fontsize=15)
plt.title('Average Salary by Title',fontsize=15)
plt.show()
